# %% [markdown]
# ### Examples from
# [Applied Plotting, Charting & Data Representation in Python (Christopher Brooks)](https://www.coursera.org/learn/python-plotting/home/welcome)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
np.random.seed(124)

v1 = pd.Series(np.random.normal(0, 10, 1000), name='v1')
v2 = pd.Series(2 * v1 + np.random.normal(60, 15, 1000), name='v2')

# %%
plt.figure()
plt.hist(v1, alpha=0.7, bins=np.arange(-50, 150, 5), label='v1')
plt.hist(v2, alpha=0.7, bins=np.arange(-50, 150, 5), label='v2')
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist([v1, v2], histtype='barstacked', normed=True)
v3 = np.concatenate((v1, v2))
sns.kdeplot(v3);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1, v2, alpha=0.4);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1, v2, kind='hex');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')
sns.jointplot(v1, v2, kind='kde', space=0);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
iris = pd.read_csv('data/iris.csv')
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.pairplot(iris, hue='variety', diag_kind='kde');
# Out:
# <img src="data:image/png;base64,..." width="1666.6666666666667">

# %%
plt.figure()
plt.subplot(121)
sns.swarmplot('variety', 'petal.length', data=iris);
plt.subplot(122)
sns.violinplot('variety', 'petal.length', data=iris);
# Out:
# <img src="data:image/png;base64,..." width="640">
